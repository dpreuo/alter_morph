# %%
import numpy as np

# %%
m1 = np.random.random((3, 3))
m2 = np.random.random((3, 3))

diag = np.random.random(3)

a = m1 * diag @ m2
b = m1 @ np.diag(diag) @ m2
a - b
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.],
#        [0., 0., 0.]])
